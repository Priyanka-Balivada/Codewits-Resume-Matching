# %%
pip install PyMuPDF
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 30.9 MB/s eta 0:00:00
# ...

# %%
import fitz
doc = fitz.open('/RohitashvaKumawat__L1.pdf')
for page in doc:
  text = page.get_text()
  print(text)
# Out:
# Rohitashva Kumawat
# rohitashvakumawat2004@gmail.com
# 91 9953969351
# Pune
# EDUCATION
# Bachelor of Technology (B.Tech), Computer Science &
# Engineering
# Vishwakarma Institute of Technology
# 2022  2026
# Senior Secondary (XII, Science
# Kendriya Vidyalaya ONGC, Panvel, Maharashtra
# CBSE board)
# Year of completion: 2022
# Percentage: 88.00%
# Secondary (X
# Kendriya Vidyalaya CRPF, Avadi Chennai, Tamil Nadu
# CBSE board)
# Year of completion: 2020
# Percentage: 89.40%
# POSITIONS OF
# RESPONSIBILITY
# FY Robotics Mentor, I am part of a mentorship program
# initiated by my college recently, I will be mentoring newly
# admitted first year students for their first academic year
# 202324 in Robotics subject.
# TRAININGS
# Introduction To Basic Game Development Using Scratch
# Coursera Project Network, Online
# Sep 2022  Sep 2022
# https://coursera.org/share/355cce6455730d6bb86a78ea25
# 3e1691
# Python Data Structures
# University Of Michigan Offered By Coursera, Online
# ...
